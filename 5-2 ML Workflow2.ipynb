# %% [markdown]
# # Machine Learning with Python

# %% [markdown]
# ## Data Read

# %%
# !cd
# Out:
# C:\Users\이태호\주피터 노트북\ML_Python

# %%
# !cat asset-v1_HGUk+HGU05+2018_T1+type@asset+block@JoyML/data/joydata.txt
# Out:
# -1.72	-3.12	1
# 0.31	1.85	1
# 1.56	2.85	1
# 2.64	2.41	1
# 1.23	2.54	1
# 1.33	2.03	1
# 1.26	2.68	1
# 2.58	1.79	1
# 2.40	0.91	1
# 0.51	2.44	1
# 2.17	2.64	1
# 3.38	2.94	1
# 1.09	3.12	1
# 0.68	1.43	1
# 3.76	0.64	1
# 0.73	2.97	1
# 0.53	2.94	1
# 1.49	1.25	1
# 3.92	3.48	1
# 3.87	2.91	1
# 1.14	3.01	1
# 1.73	2.80	1
# 2.96	1.84	1
# 2.61	2.92	1
# 2.28	0.90	1
# 1.93	3.71	1
# 1.26	1.17	1
# 1.90	1.34	1
# 3.13	0.92	1
# 0.85	1.46	1
# 1.50	3.93	1
# 2.95	2.09	1
# 0.76	2.84	1
# 1.00	0.46	1
# 3.19	2.32	1
# 2.82	2.32	1
# 2.86	1.35	1
# 0.97	2.68	1
# 1.20	1.31	1
# 1.54	2.02	1
# 1.74	0.63	1
# 1.36	-0.22	1
# 2.63	0.40	1
# 0.90	2.05	1
# 1.26	2.54	1
# 0.71	2.27	1
# 1.96	0.83	1
# 2.52	1.83	1
# 2.76	2.82	1
# 3.16	3.34	1
# 1.10	-1.14	0
# -1.33	0.34	0
# 0.76	-3.07	0
# -0.37	-1.91	0
# -1.84	-1.11	0
# -1.50	0.24	0
# -0.63	-1.53	0
# -1.08	-1.23	0
# 0.29	-1.99	0
# -1.26	-2.90	0
# -5.27	-1.78	0
# -0.49	-2.64	0
# 1.28	-3.64	0
# -1.64	-1.96	0
# 0.25	-1.26	0
# -1.48	-1.17	0
# -2.94	-3.47	0
# -2.19	-1.48	0
# 0.52	-0.02	0
# -2.24	-2.12	0
# -3.07	-2.09	0
# -3.99	0.73	0
# -2.41	-2.21	0
# -3.45	-0.62	0
# -3.96	-2.00	0
# -2.95	-1.16	0
# -2.42	-3.35	0
# -1.64	-1.11	0
# -1.61	-1.28	0
# -2.59	-2.21	0
# -2.64	-2.20	0
# -2.84	-3.22	0
# -1.45	-2.26	0
# -3.08	-1.05	0
# -2.97	-1.53	0
# -0.68	-1.52	0
# -0.11	-3.43	0
# -1.14	-2.66	0
# -2.92	-2.51	0
# -2.14	-1.52	0
# -3.02	-0.44	0
# -1.05	-3.85	0
# 0.28	-1.25	0
# -0.05	-1.95	0
# -3.20	-0.22	0
# -2.26	0.01	0
# -1.41	-0.23	0
# -1.20	-0.71	0
# -1.69	0.70	0
# -1.52	-1.14	0

# %% [markdown]
# ## Data Bias

# %%
import numpy as np
data = np.genfromtxt('asset-v1_HGUk+HGU05+2018_T1+type@asset+block@JoyML/data/joydata.txt')
x, y = data[:, :2], data[:, 2]
y = y.astype(np.int)
print(x[:5], y[:5])
print(x[-5:], y[-5:])
# Out:
# [[-1.72 -3.12]
#  [ 0.31  1.85]
#  [ 1.56  2.85]
#  [ 2.64  2.41]
#  [ 1.23  2.54]] [1 1 1 1 1]
# [[-2.26  0.01]
#  [-1.41 -0.23]
#  [-1.2  -0.71]
#  [-1.69  0.7 ]
#  [-1.52 -1.14]] [0 0 0 0 0]

# %% [markdown]
# ## Shuffling

# %%
import numpy as np
data = np.genfromtxt('asset-v1_HGUk+HGU05+2018_T1+type@asset+block@JoyML/data/joydata.txt')
np.random.shuffle(data)

x, y = data[:, :2], data[:,2]
y = y.astype(np.int)

print(x[:5], y[:5])
print(x[-5:], y[-5:])
# Out:
# [[-2.24 -2.12]
#  [-0.11 -3.43]
#  [ 2.28  0.9 ]
#  [-1.69  0.7 ]
#  [ 2.58  1.79]] [0 0 1 0 1]
# [[ 2.17  2.64]
#  [ 1.9   1.34]
#  [ 1.23  2.54]
#  [-0.49 -2.64]
#  [-3.2  -0.22]] [1 1 1 0 0]

# %% [markdown]
# ## Feature Scaling
# : if feature's range are so different) like age & property

# %% [markdown]
# ### Normalization (min-max scaling)
#
# _data range: between 0 and 1_
#
# _how to compute: Xnorm = (X - Xmin) / (Xmax - Xmin)_

# %%
xmax = np.max(x)
xmin = np.min(x)
x = (x - xmin) / (xmax - xmin)

# %% [markdown]
# ### Standardization
#
# _less affected by unusual value_
#
# _data range: mean = 0, standard deviation = 1_

# %%
from IPython.display import Image

# %%
Image(filename= './images/05_01.png', width=300)

# %%
mu = x.mean(axis=0)
sigma = x.std(axis=0)
x = (x - mu) / sigma

# %% [markdown]
# ## Data Separation (train, test)

# %%
import numpy as np
data = np.genfromtxt('asset-v1_HGUk+HGU05+2018_T1+type@asset+block@JoyML/data/joydata.txt')
np.random.seed(1)
np.random.shuffle(data)

x, y = data[:, :2], data[:, 2]
y = y.astype(np.int)

num = int(x.shape[0] * 0.8) # percentage
x_train, x_test = x[:num], x[num:]
y_train, y_test = y[:num], y[num:]

# %% [markdown]
# ## Data Visualization (shuffling)

# %%
import matplotlib.pylab as plt
# %matplotlib inline
## remove 1st column before plotting; change shape(mx3) into shape(mx2) or use x_train, x_test
## x_train = X_train[ : , 1:]     

fig, ax = plt.subplots(1, 2, sharex=True, sharey=True,figsize=(10, 4))
ax[0].scatter(x_train[y_train==1, 0], x_train[y_train==1, 1], label='class 1', marker='s')
ax[0].scatter(x_train[y_train==0, 0], x_train[y_train==0, 1], label='class 2', marker='o')
ax[1].scatter(x_test[y_test==1, 0], x_test[y_test==1, 1], label='class 1', marker='s')
ax[1].scatter(x_test[y_test==0, 0], x_test[y_test==0, 1], label='class 2', marker='o')
ax[0].set_title('Training dataset')
ax[1].set_title('Test dataset')
ax[0].set_xlabel('x1')
ax[0].set_ylabel('x2')
ax[0].legend()
plt.show()

# %% [markdown]
# ## Data Visualization (normalization)

# %%
import numpy as np
data = np.genfromtxt('asset-v1_HGUk+HGU05+2018_T1+type@asset+block@JoyML/data/joydata.txt')
np.random.seed(1)
np.random.shuffle(data)

x, y = data[:, :2], data[:, 2]
y = y.astype(np.int)

xmax = np.max(x)
xmin = np.min(x)
x = (x - xmin) / (xmax - xmin)

num = int(x.shape[0] * 0.8)
x_train, x_test = x[:num], x[num:]
y_train, y_test = y[:num], y[num:]

# %%
import matplotlib.pylab as plt
# %matplotlib inline

fig, ax = plt.subplots(1, 2, sharex=True, sharey=True,figsize=(10, 4))
ax[0].scatter(x_train[y_train==1, 0], x_train[y_train==1, 1], label='class 1', marker='s')
ax[0].scatter(x_train[y_train==0, 0], x_train[y_train==0, 1], label='class 2', marker='o')
ax[1].scatter(x_test[y_test==1, 0], x_test[y_test==1, 1], label='class 1', marker='s')
ax[1].scatter(x_test[y_test==0, 0], x_test[y_test==0, 1], label='class 2', marker='o')
ax[0].set_title('Training dataset')
ax[1].set_title('Test dataset')
ax[0].set_xlabel('x1')
ax[0].set_ylabel('x2')
ax[0].legend()
plt.show()

# %% [markdown]
# ## Data Visualization (standardization)

# %%
import numpy as np
data = np.genfromtxt('asset-v1_HGUk+HGU05+2018_T1+type@asset+block@JoyML/data/joydata.txt')
np.random.seed(1)
np.random.shuffle(data)

x, y = data[:, :2], data[:, 2]
y = y.astype(np.int)

mu = x.mean(axis=0)
sigma = x.std(axis=0)
x = (x - mu) / sigma

num = int(x.shape[0] * 0.8)
x_train, x_test = x[:num], x[num:]
y_train, y_test = y[:num], y[num:]

# %%
import matplotlib.pylab as plt
# %matplotlib inline

fig, ax = plt.subplots(1, 2, sharex=True, sharey=True,figsize=(10, 4))
ax[0].scatter(x_train[y_train==1, 0], x_train[y_train==1, 1], label='class 1', marker='s')
ax[0].scatter(x_train[y_train==0, 0], x_train[y_train==0, 1], label='class 2', marker='o')
ax[1].scatter(x_test[y_test==1, 0], x_test[y_test==1, 1], label='class 1', marker='s')
ax[1].scatter(x_test[y_test==0, 0], x_test[y_test==0, 1], label='class 2', marker='o')
ax[0].set_title('Training dataset')
ax[1].set_title('Test dataset')
ax[0].set_xlabel('x1')
ax[0].set_ylabel('x2')
ax[0].legend()
plt.show()

# %% [markdown]
# ## add bias to feature X

# %%
x, y = data[:, :2], data[:, 2]
y = y.astype(np.int)

num = int(x.shape[0] * 0.8)
x_train, x_test = x[:num], x[num:]
y_train, y_test = y[:num], y[num:]

X_train = np.c_[ np.ones(len(x_train)), x_train ]
X_test  = np.c_[ np.ones(len(x_test)), x_test ]
print(X_train[:5])
# Out:
# [[ 1.   -2.64 -2.2 ]
#  [ 1.   -2.97 -1.53]
#  [ 1.    1.    0.46]
#  [ 1.   -2.84 -3.22]
#  [ 1.   -0.05 -1.95]]

# %% [markdown]
# ## Learning Step: using perceptron

# %%
def perceptron_train(X, y, X0=False, eta=0.1, epochs=1, random_seed=1):
    """  Perceptron training function for binary class labels
    Input Parameters
        X : numpy.ndarray, shape=(n_samples, m_features), by default X0=False
            A 2D NumPy array containing the training examples
            or 
            If X0=True, X's shape=(n_samples, m_features+1) 
            It includes the bias or x0 = 1 for all samples 
        
        y : numpy.ndarray, shape=(n_samples,)
            A 1D NumPy array containing the true class labels
        
        X0: If True, then X must have X_0 = 1 in all samples.
             Set it Faslse, if X does not have X_0 
        
        eta : float (default: 0.1) 
            A learning rate for the parameter updates. Note that a learning
            rate has no effect on the direction of the decision boundary
            if the model weights are initialized to all zeros.
        
        epochs : int (default: 1), Number of passes over the training dataset.
        
        random_seed : int or None (default: 1)
            Seed for the pseudo-random number generator that initializes the
            weights w if w is None.
    
    Returns 
        w : numpy.ndarray, shape=(m_features, )
    
        If you wants W : numpy.ndarray, shape=(epochs, m_features) to use 
        when calling , then invoke this function with epochs = 1 multiple times 
        and save the result in the form of W = np.vstack([W, w]). 
        You may initialize the W = np.array([w]), where w is an initial weights.
    """
    if X0 == False:
        X = np.c_[ np.ones(len(X)), X ]
    
    randnum = np.random.RandomState(random_seed) 
    w = randnum.normal(loc=0.0, scale=0.01, size=X.shape[1])
           
    maxlabel, minlabel = y.max(), y.min()                 # for use of bipolar or unit step function
    for _ in range(epochs):
        for xi, yi in zip(X, y):
            z = np.dot(xi, w)                             # Compute net input, same as np.dot(w.T, x)
            yhat = np.where(z > 0.0, maxlabel, minlabel)  # Apply unit step func and get output
            #print('xi{}, \t (yi,yhat)=({},{})'.format(np.round(xi,2), yi, yhat))
            if yi != yhat:
                delta = eta * (yi - yhat) * xi                # Compute delta    
                w += delta                                    # Adjust weight
                #print('xi{}, \t (yi,yhat)=({},{}), delta{}, w{}'.format
                #         (np.round(xi,2), yi, yhat, np.round(delta,2), np.round(w,2)))
        
    return w

# %% [markdown]
# ### Perceptron Call

# %%
print(X_train[:5])
print(y_train[:5])
w = perceptron_train(X_train, y_train, X0=True, eta=0.02, epochs=1, random_seed=2)
print('w = ', w)
# Out:
# [[ 1.   -2.64 -2.2 ]
#  [ 1.   -2.97 -1.53]
#  [ 1.    1.    0.46]
#  [ 1.   -2.84 -3.22]
#  [ 1.   -0.05 -1.95]]
# [0 0 1 0 0]
# w =  [-0.02416758  0.04263733  0.01383804]

# %% [markdown]
# ## Prediction and Evaluation stage: binary perceptron

# %%
def perceptron_predict(X, w):
    z = np.dot(X, w)
    yhat = np.where(z > 0., 1, 0)
    return yhat

# %%
#version 0.1
yhat = perceptron_predict(X_train, w)
missed = 0 #misclassified count
m_samples = len(y_train)
for m in range(m_samples):
    if yhat[m] != y_train[m]:
        missed += 1
print('Misclassified:{}/{}'.format(missed, m_samples))
# Out:
# Misclassified:1/80

# %%
#version 0.1
yhat = perceptron_predict(X_test, w)
missed = 0 #misclassified count
m_samples = len(y_test)
for m in range(m_samples):
    if yhat[m] != y_test[m]:
        missed += 1
print('Misclassified:{}/{}'.format(missed, m_samples))
# Out:
# Misclassified:1/20

# %%
#version 0.2
yhat = perceptron_predict(X_test, w)
missed = np.sum(yhat.flatten() != y_test)
print("Misclassified:{}/{}".format(missed, m_samples))
# Out:
# Misclassified:1/20

# %% [markdown]
# ## Prediction and Evaluation stage: visualization

# %%
# %run asset-v1_HGUk+HGU05+2018_T1+type@asset+block@JoyML/code/plot_xyw.py
plot_xyw(X_train, y_train, w.flatten(), X0=True)

# %%
plot_xyw(X_test, y_test, w.flatten(), X0=True)
